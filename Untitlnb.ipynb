# %% [markdown]
#  1 - What is the difference between 'Paste' and 'Paste Special' in Excel? Briefly explain with examples.
#
#  In Excel, the “Paste” and “Paste Special” commands are both used to insert copied data, but they work in different ways. The Paste option simply places everything that was copied — including values, formulas, formatting, and comments — into the selected cells. For example, if cell A1 contains the formula =B1+C1 and has a yellow background, using Paste (Ctrl + V) in cell A2 will copy the same formula (adjusted to =B2+C2), along with the yellow colour and any comments.
#
# On the other hand, Paste Special provides more control over what you paste. It allows you to paste only specific parts of the copied data such as values, formulas, formats, or even transpose rows and columns. For instance, if you use Paste Special → Values, only the result of the formula in A1 will be pasted into A2, not the actual formula or formatting. Similarly, Paste Special → Formats would copy only the yellow background, while Transpose would switch rows into columns. In short, Paste copies everything as it is, whereas Paste Special lets you choose exactly what to paste and how.
#
# - 2 Describe the functions and usefulness of 'Freeze Panes' and 'Split Panes'
# in Excel.
#
# Freeze Panes
#
# Function:
# The Freeze Panes feature allows you to lock specific rows or columns so that they remain visible while you scroll through the rest of the worksheet. This is particularly useful when working with large datasets where the header row or labels need to stay in view for easy reference.
#
# Usefulness:
#
# Helps keep column headings or row labels visible at all times.
#
# Makes data comparison easier when scrolling through long lists.
#
# Prevents confusion when dealing with large tables.
#
# Example:
# If you have headings in the first row (like “Name”, “Age”, “Salary”, “City”), you can go to the View tab → Freeze Panes → Freeze Top Row.
# Now, when you scroll down, the header row stays visible even as you move through hundreds of rows below.
#
# Options under Freeze Panes:
#
# Freeze Panes: Locks both rows and columns above and to the left of the active cell.
#
# Freeze Top Row: Keeps only the top row visible.
#
# Freeze First Column: Keeps only the first column visible.
#
# 🔹 Split Panes
#
# Function:
# The Split Panes feature divides the worksheet into two or four independent sections (panes), allowing you to scroll each section separately. It helps in viewing and comparing different parts of a large worksheet simultaneously.
#
# Usefulness:
#
# Useful for comparing data from distant parts of the same sheet.
#
# Allows you to view multiple sections of a worksheet side by side.
#
# Helps in cross-checking or editing data located in different areas.
#
# Example:
# If you select a cell in the middle of the sheet and choose View tab → Split, Excel divides the screen into four parts. You can scroll in one pane without affecting the others. For instance, you could view the top and bottom of a long data list at the same time.
#
#
#
# - 3 Explain the difference between inserting a new row and inserting a new
# column in Excel. Can you insert multiple rows or columns at once?
#
#
# Inserting a New Row
#
# Meaning:
# When you insert a new row, Excel adds a horizontal line of empty cells above the selected row. All the existing rows below that point move downward by one position.
#
# Example:
# If you have data in rows 1 to 10 and you insert a new row above row 5, the new blank row becomes Row 5, and the old row 5 becomes Row 6.
#  Use the shortcut: Ctrl + Shift + “+” (after selecting an entire row).
#
# Usefulness:
#
# To add new entries in between existing data.
#
# To create space for totals, comments, or additional information.
#
# 🔹 Inserting a New Column
#
# Meaning:
# When you insert a new column, Excel adds a vertical strip of empty cells to the left of the selected column. All existing columns to the right shift one position to the right.
#
# Example:
# If you have data in columns A to E and you insert a new column before column C, the new column becomes Column C, and the old column C becomes Column D. Shortcut: Ctrl + Shift + “+” (after selecting an entire column).
#
# Usefulness:
#
# To add new fields or categories, such as adding a “Bonus” column between “Salary” and “Total Pay”.
#
# 🔹 Inserting Multiple Rows or Columns
#
# Yes, you can insert multiple rows or columns at once.
#
# Methods:
#
# Select multiple rows or columns first, then right-click and choose Insert.
#
# Example: Select 3 rows → Right-click → Insert → 3 new rows appear.
#
# Use the Home tab → Insert → Insert Sheet Rows/Columns.
#
# Example:
# If you select Rows 4 to 6 and choose Insert, Excel will insert three new blank rows above row 4.
# Similarly, selecting Columns B to D and choosing Insert adds three new blank columns to the left of column B.
#
#
#
# 4 What are logical functions in Excel? Provide examples of at least two
# logical functions and their applications.
#
#
# - Definition:
#
#  - Logical functions check a condition and then return a specific output depending on whether the condition is true or false.
#
#  - Example of use:
# Checking if a student has passed or failed, or determining if sales targets have been met.
#
# 🔹 Common Logical Functions:
#  - 1. IF Function
#
#  - Purpose:
# The IF function tests a condition and returns one value if the condition is TRUE and another value if it is FALSE.
#
#  - Syntax:
#
#  - =IF(logical_test, value_if_true, value_if_false)
#
#
#  - Example:
# If a student’s marks are in cell A1,
#
#  - =IF(A1>=40, "Pass", "Fail")
#
#
#  - Explanation:
#
#  - If the marks are 40 or more, Excel shows “Pass”.
#
#  - If the marks are less than 40, Excel shows “Fail”.
#
#  - Application:
# Useful in grading systems, salary calculations (bonus or no bonus), and other decision-based tasks.
#
#  - 2. AND Function
#
#  - Purpose:
# The AND function checks multiple conditions and returns TRUE only if all conditions are true; otherwise, it returns FALSE.
#
#  - Syntax:
#
#  - =AND(condition1, condition2, ...)
#
#
#  - Example:
# To check if a student passes both subjects:
#
#  -=AND(A1>=40, B1>=40)
#
#
#  - Explanation:
#
#  - Returns TRUE if marks in both subjects are 40 or above.
#
#  - Returns FALSE if even one subject has marks below 40.
#
#  - Application:
# Commonly used in eligibility checks, performance evaluations, and filtering data based on multiple criteria.
#
#
#  5- Discuss the purpose of 'XLOOKUP' and how it differs from the traditional
# 'VLOOKUP' function.
#
# The XLOOKUP function in Excel is a modern and more powerful replacement for the traditional VLOOKUP function. Its main purpose is to search for a specific value in a range and return a matching value from another range. Unlike VLOOKUP, which can only look for data from left to right, XLOOKUP can search both left and right, making it much more flexible. For example, if you want to find an employee’s salary based on their name, you can use the formula =XLOOKUP("Rahul", A2:A10, B2:B10, "Not Found"). This will look for “Rahul” in column A and return the matching salary from column B, and if no match is found, it will display “Not Found.”
#
# VLOOKUP, on the other hand, uses a column index number and can only search vertically from left to right, which means if the lookup column is not the first one, the formula won’t work properly. It also breaks easily if you insert new columns in your table. XLOOKUP removes these limitations by directly referencing the lookup and return ranges. It also allows you to customise what to show if no match is found, supports both vertical and horizontal lookups, and works faster with large datasets. In short, XLOOKUP is more efficient, flexible, and reliable than VLOOKUP, making it the preferred choice in modern versions of Excel.
#
# - - 6 a worksheet titled 'Employee Data' with columns: Name, Age,
# Department. Add 5 rows of data.
# Format as follows:
# ● Bold and center-align the header row
# ● Apply a fill color
# ● Auto-fit column width
# (Include a screenshot showing your formatted table.)
# ![Screenshot (6).png](data:image/png;base64,...)
# - 7Demonstrate how to insert and delete multiple rows and columns in Excel.
# Step 1: Inserting Multiple Rows
#
# Select the number of rows you want to insert.
#
# Example: To insert 3 new rows above row 5, select Rows 5, 6, and 7.
#
# Right-click the selected rows.
#
# Click Insert.
#
# Excel will add 3 new blank rows above the first selected row.
#
# Shortcut method:
#
# Select rows → Press Ctrl + Shift + “+” → New rows will be inserted above.
#
# 🔹 Step 2: Inserting Multiple Columns
#
# Select the number of columns you want to insert.
#
# Example: To insert 2 new columns before column C, select Columns C and D.
#
# Right-click the selected columns.
#
# Click Insert.
#
# Two new blank columns will appear to the left of column C.
#
# Shortcut method:
#
# Select columns → Press Ctrl + Shift + “+” → New columns will be inserted to the left.
#
# 🔹 Step 3: Deleting Multiple Rows or Columns
#
# Select the rows or columns you want to delete.
#
# Example: Select Rows 4–6 or Columns B–D.
#
# Right-click on the selection.
#
# Click Delete.
#
# The selected rows or columns will be removed, and the remaining data will shift up or left.
#
# Shortcut method:
#
# Select rows/columns → Press Ctrl + “–” (minus) → Deletes them immediately.
#
#
# : Use Excel's 'Find and Replace' feature to update department names in a
# sample table.
#
# ![ChatGPT Image Oct 9, 2025, 05_31_53 PM.png](data:image/png;base64,...)
#
#
# Create a small numerical dataset and apply the following functions:
# ● AVERAGE
# ● MAX
# ● MIN
# Step 1: Create a Small Numerical Dataset
# A (Name)	B (Marks)
# Rahul	78
# Neha	85
# Arjun	92
# Priya	67
# Aman	74
# Step 2: Apply the Functions
#
# AVERAGE Function:
# Formula → =AVERAGE(B2:B6)
# ✅ This will calculate the average of all marks → 79.2
#
# MAX Function:
# Formula → =MAX(B2:B6)
# ✅ This will show the highest mark → 92
#
#
# MIN Function:
# Formula → =MIN(B2:B6)
# ✅ This will show the lowest mark → 67
#
# 10: You're working with a dataset that contains missing values. As a Data
# Scientist, explain how you'd detect and handle missing data using Excel.
# Mention tools like:
# ● Go To Special
# ● ISBLANK
# ● COUNTBLANKStep 1: Detect Missing Data Using “Go To Special”
#
# Tool: Go To Special → Blanks
#
# How to Use:
#
# Select your dataset (e.g., A1:C10).
#
# Press Ctrl + G → Click Special… → Select Blanks → Click OK.
#
# Excel will instantly highlight all empty cells.
#
# ✅ Usefulness:
# This helps visually identify which cells have missing values so you can decide whether to fill, delete, or replace them.
#
# Step 2: Detect Missing Data Using “ISBLANK” Function
#
# Function: =ISBLANK(cell_reference)
#
# How to Use:
#
# Example: In cell D2, type
# =ISBLANK(B2)
#
# If B2 is empty, Excel shows TRUE.
#
# If B2 has data, it shows FALSE.
#
# ✅ Usefulness:
# This helps you find blanks one by one and even combine with filters to analyse missing entries.
#
# Step 3: Count Total Missing Cells Using “COUNTBLANK”
#
# Function: =COUNTBLANK(range)
#
# How to Use:
#
# Example:
# =COUNTBLANK(B2:B10)
#
# It returns the total number of empty cells in that range.
#
# ✅ Usefulness:
# Gives you a quick numerical summary of how many cells are missing data in your dataset.
#
# Step 4: Handling Missing Data
#
# Once you’ve detected blanks, you can handle them in several ways:
#
# Fill Missing Values:
#
# Use average or median values to fill missing numbers.
#
# For text, use “N/A” or “Unknown”.
#
# Delete Rows/Columns:
#
# If blanks are too many, delete the affected rows/columns.
#
# Use filters or Go To Special → Blanks → Delete Rows.
#
# Use Conditional Formatting:
#
# Highlight blanks (Home → Conditional Formatting → New Rule → Format only cells that are blank) to make them visible for correction.
